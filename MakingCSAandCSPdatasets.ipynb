# %%
import pandas as pd
import numpy as np

# %%
df_sheet_multi = pd.read_excel("/Users/leahokamura/CS290/CS290FinalProject/data/CSP-2017-2021-By-State.xlsx", sheet_name=None)

# %%
df_sheet_multi["Arkansas"]
# Out:
#    Year   Total   Total Passed   % Passed  Num Black   Black Passed  \
# 0  2017     492            228      46.34         49             13
# 1  2018     781            361      46.22         83             11
# 2  2019     851            455      53.47         98             23
# 3  2020     939            494      52.61        103             33
# 4  2021     952            462      48.53         69             13
#
#     % Black Passed   % Black  Num Hispanic   Hisp Passed  ...   % Male NA  \
# 0            26.53      9.96            62            25  ...        0.41
# 1            13.25     10.63            76            28  ...        0.77
# 2            23.47     11.52            87            39  ...        0.47
# 3            32.04     10.97            93            47  ...        1.28
# 4            18.84      7.25            98            31  ...        0.74
#
#    Num 2+ Male   Male 2+ Passed   % Male 2+ Passed   % Male 2+  \
# ...

# %%
for i in df_sheet_multi:
    df_sheet_multi[i]["State"]=i

# %%
df_sheet_multi["Alabama"]
# Out:
#    Year   Total   Total Passed   % Passed  Num Black   Black Passed  \
# 0  2017    1249            816      65.33        143             52
# 1  2018    1607            911      56.69        216             81
# 2  2019    1969           1064      54.04        264             69
# 3  2020    1892           1047      55.34        311            144
# 4  2021    2064           1103      53.44        253             63
#
#     % Black Passed   % Black  Num Hispanic   Hisp Passed  ...  Num 2+ Male  \
# 0            36.36     11.45            69            37  ...           43
# 1            37.50     13.44            97            44  ...           49
# 2            26.14     13.41           135            53  ...           51
# 3            46.30     16.44           142            75  ...           58
# 4            24.90     12.26           151            68  ...           65
#
#     Male 2+ Passed   % Male 2+ Passed   % Male 2+  Num Other Male  \
# ...

# %%
df = pd.concat(df_sheet_multi, ignore_index=True)

# %%
df.to_csv("data/CSP_ALL.csv")

# %%
df_sheet_multi2 = pd.read_excel("/Users/leahokamura/CS290/CS290FinalProject/data/CSA-2010-2021-By-State.xlsx", sheet_name=None)

# %%
for i in df_sheet_multi2:
    df_sheet_multi2[i]["State"]=i

# %%
df2 = pd.concat(df_sheet_multi2, ignore_index=True)

# %%
df2.to_csv("data/CSA_ALL.csv")

# %%
df2
# Out:
#      Year   Total   Total Passed   % Passed  Num Black   Black Passed  \
# 0    2010     104             52      50.00         11              3
# 1    2011      99             61      61.62         18              5
# 2    2012      97             61      62.89          9              5
# 3    2013     126             99      78.57          8              6
# 4    2014     197            111      56.35         20              5
# ..    ...     ...            ...        ...        ...            ...
# 607  2017       8              5      62.50          0              0
# 608  2018      11              5      45.45          0              0
# 609  2019      13             11      84.62          0              0
# 610  2020      22             19      86.36          0              0
# 611  2021      26             22      84.62          0              0
#
#       % Black Passed   % Black  Num Hispanic   Hisp Passed  ...  Num 2+ Male  \
# ...
